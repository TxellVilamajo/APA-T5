# %% [markdown]
# # COMPROVACIÓ DEL FUNCIONAMENT DE LES FUNCIONS

# %%
run estereo

# %% [markdown]
# ### estereo2mono

# %%
estereo2mono("komm.wav", "beatles_L.wav", canal=0)

# %%
estereo2mono("komm.wav", "beatles_R.wav", canal=1)

# %%
estereo2mono("komm.wav", "beatles_Suma.wav", canal=2)

# %%
estereo2mono("komm.wav", "beatles_Diferenciaa.wav", canal=3)

# %% [markdown]
# ### mono2estereo

# %%
mono2estereo("beatles_L.wav", "beatles_R.wav", "beatles_reconstruit.wav")

# %% [markdown]
# ### codEstereo

# %%
codEstereo("komm.wav", "beatles_ocult_32bit.wav")

# %% [markdown]
# ### decEstereo

# %%
decEstereo("beatles_ocult_32bit.wav", "beatles_recuperat_final.wav")
